# %% [markdown]
# <a href="https://colab.research.google.com/github/raguram/DenseDepth/blob/master/S15/DataVisualization_Assignment15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os.path import join
from google.colab import drive

ROOT = "/content/drive"
drive.mount(ROOT, force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Download the data

# %%
# !rm -rf /content/input

# %%
# !unzip /content/drive/My\ Drive/Colab\ Notebooks/workspace/data/Assignment15/data.zip -d /content/input
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/input/fg_bg/Image_359228.jpg
#  extracting: /content/input/fg_bg/Image_359229.jpg
#  extracting: /content/input/fg_bg/Image_359230.jpg
#  extracting: /content/input/fg_bg/Image_359231.jpg
#  extracting: /content/input/fg_bg/Image_359232.jpg
#  extracting: /content/input/fg_bg/Image_359233.jpg
#  extracting: /content/input/fg_bg/Image_359234.jpg
#  extracting: /content/input/fg_bg/Image_359235.jpg
#  extracting: /content/input/fg_bg/Image_359236.jpg
#  extracting: /content/input/fg_bg/Image_359237.jpg
#  extracting: /content/input/fg_bg/Image_359238.jpg
#  extracting: /content/input/fg_bg/Image_359239.jpg
#  extracting: /content/input/fg_bg_mask/Image_359220.jpg
#  extracting: /content/input/fg_bg_mask/Image_359221.jpg
#  extracting: /content/input/fg_bg_mask/Image_359222.jpg
#  extracting: /content/input/fg_bg_mask/Image_359223.jpg
#  extracting: /content/input/fg_bg_mask/Image_359224.jpg
# ...

# %%
from os import listdir
from os.path import join

fg_bg_images = [join("", f) for f in listdir("/content/input/fg_bg_mask")]

print(len(fg_bg_images))
# Out:
# 361720
